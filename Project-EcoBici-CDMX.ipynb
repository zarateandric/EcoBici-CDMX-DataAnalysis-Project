# %% [markdown]
# # Eco-Bici CDMX

# %% [markdown]
# ## 1. Extract & Load of data

# %% [markdown]
# ### 1.1: Preparing environment

# %% [markdown]
# Installing libraries: pandas, requests beautifulsoup4

# %%
# !pip install requests pandas beautifulsoup4
# Out:
# Requirement already satisfied: requests in z:\andric\programas\anaconda\lib\site-packages (2.32.3)
# Requirement already satisfied: pandas in z:\andric\programas\anaconda\lib\site-packages (2.2.2)
# Requirement already satisfied: beautifulsoup4 in z:\andric\programas\anaconda\lib\site-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in z:\andric\programas\anaconda\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in z:\andric\programas\anaconda\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in z:\andric\programas\anaconda\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in z:\andric\programas\anaconda\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: numpy>=1.26.0 in z:\andric\programas\anaconda\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in z:\andric\programas\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in z:\andric\programas\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in z:\andric\programas\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: soupsieve>1.2 in z:\andric\programas\anaconda\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: six>=1.5 in z:\andric\programas\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# ### 1.2: Exploring EcoBici Web

# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# define URL page that contains the data 
url_main_page = "https://ecobici.cdmx.gob.mx/datos-abiertos/"

# %%
# using request to get information
print("Exploring the page")
page = requests.get(url_main_page)
print("Page obtained")
# Out:
# Exploring the page
# Page obtained

# %%
# HTML lecture
soup = BeautifulSoup(page.content,"html.parser")

# %%
# looking and finding <a> labels
all_links = soup.find_all('a')

for links in (all_links):
    print(f"Found {links} <a> labels")

print(f"\nTotal <a> labels found: {len(all_links)}")
# Out:
# Found <a href="/">
# <img alt="Ecobici" class="c-header__logo-img c-header__logo-img--desktop" src="/wp-content/uploads/2022/06/0ecobici-gob_logo.png"/>
# <img alt="Ecobici" class="c-header__logo-img c-header__logo-img--mobile" src="/wp-content/uploads/2022/06/0ecobici-gob_logo.png"/>
# </a> <a> labels
# Found <a class="c-button c-button--small c-header_mobile-book-now" href="https://usuario.ecobici.cdmx.gob.mx/">Regístrate</a> <a> labels
# Found <a>Ecobici</a> <a> labels
# Found <a href="/conoce-sistema/">Conoce Ecobici</a> <a> labels
# Found <a aria-current="page" href="/datos-abiertos/">Datos Abiertos</a> <a> labels
# Found <a href="/encuestas-y-estudios-de-uso/">Encuestas y estudios</a> <a> labels
# Found <a href="/informacion-ciclista/">Información ciclista</a> <a> labels
# Found <a href="/estadisticas/">Estadísticas</a> <a> labels
# Found <a>▾</a> <a> labels
# Found <a href="/planes-y-tarifas/">Planes y tarifas</a> <a> labels
# Found <a href="/mapa/">Mapa</a> <a> labels
# Found <a href="/conoce-la-app/">Conoce la App</a> <a> labels
# Found <a href="/noticias/">Noticias</a> <a> labels
# Found <a href="/preguntas-frecuentes/">Preguntas frecuentes</a> <a> labels
# Found <a href="/contacto/">Contacto</a> <a> labels
# Found <a href="https://usuario.ecobici.cdmx.gob.mx/sign-in" style="font-family: Source Sans Pro;font-style: normal;font-weight: bold;font-size: 14px;line-height: 109.7%;text-decoration: underline;color: #009a44">Soy usuario registrado</a> <a> labels
# Found <a href="/en/welcome" style="font-family: Source Sans Pro;font-style: normal;font-weight: 400;font-size: 14px;line-height: 109.7%">Inglés </a> <a> labels
# Found <a href="/" style="font-family: Source Sans Pro;font-style: normal;font-weight: 400;font-size: 14px;line-height: 109.7%"> Español</a> <a> labels
# Found <a class="c-soc__link" href="https://es-la.facebook.com/ecobici/" target="_blank"><i class="ip-facebook c-soc__icon c-soc__icon--facebook">
# <!-- --></i></a> <a> labels
# Found <a class="c-soc__link" href="https://www.instagram.com/ecobicicdmx/?hl=es" target="_blank"><i class="ip-instagram c-soc__icon c-soc__icon--instagram">
# <!-- --></i></a> <a> labels
# Found <a class="c-soc__link" href="https://twitter.com/ecobici" target="_blank"><i class="ip-twitter c-soc__icon c-soc__icon--twitter">
# <!-- --></i></a> <a> labels
# Found <a href="https://usuario.ecobici.cdmx.gob.mx/sign-in" style="font-family: Source Sans Pro;font-style: normal;font-weight: bold;font-size: 14px;line-height: 109.7%;text-decoration: underline;color: #009a44">Soy usuario registrado</a> <a> labels
# Found <a href="/en/welcome" style="font-family: Source Sans Pro;font-style: normal;font-weight: 400;font-size: 14px;line-height: 109.7%">Inglés </a> <a> labels
# Found <a href="/" style="font-family: Source Sans Pro;font-style: normal;font-weight: 400;font-size: 14px;line-height: 109.7%"> Español</a> <a> labels
# Found <a class="c-soc__link" href="https://es-la.facebook.com/ecobici/" target="_blank"><i class="ip-facebook c-soc__icon c-soc__icon--facebook">
# <!-- --></i></a> <a> labels
# Found <a class="c-soc__link" href="https://www.instagram.com/ecobicicdmx/?hl=es" target="_blank"><i class="ip-instagram c-soc__icon c-soc__icon--instagram">
# <!-- --></i></a> <a> labels
# Found <a class="c-soc__link" href="https://twitter.com/ecobici" target="_blank"><i class="ip-twitter c-soc__icon c-soc__icon--twitter">
# <!-- --></i></a> <a> labels
# Found <a href="/">
# <img alt="Ecobici" class="c-header__logo-img c-header__logo-img--desktop" src="/wp-content/uploads/2022/06/0ecobici-gob_logo.png"/>
# <img alt="Ecobici" class="c-header__logo-img c-header__logo-img--mobile" src="/wp-content/uploads/2022/06/0ecobici-gob_logo.png"/>
# </a> <a> labels
# Found <a>Ecobici</a> <a> labels
# Found <a href="/conoce-sistema/">Conoce Ecobici</a> <a> labels
# Found <a aria-current="page" href="/datos-abiertos/">Datos Abiertos</a> <a> labels
# Found <a href="/encuestas-y-estudios-de-uso/">Encuestas y estudios</a> <a> labels
# Found <a href="/informacion-ciclista/">Información ciclista</a> <a> labels
# Found <a href="/estadisticas/">Estadísticas</a> <a> labels
# Found <a>▾</a> <a> labels
# Found <a href="/planes-y-tarifas/">Planes y tarifas</a> <a> labels
# Found <a href="/mapa/">Mapa</a> <a> labels
# Found <a href="/conoce-la-app/">Conoce la App</a> <a> labels
# Found <a href="/noticias/">Noticias</a> <a> labels
# Found <a href="/preguntas-frecuentes/">Preguntas frecuentes</a> <a> labels
# Found <a href="/contacto/">Contacto</a> <a> labels
# Found <a class="c-button c-header_book-now" href="https://usuario.ecobici.cdmx.gob.mx/">Regístrate		<i class="ip-z-arrow-right c-header_book-now-ico"></i></a> <a> labels
# Found <a download="" href="https://gbfs.mex.lyftbikes.com/gbfs/gbfs.json" rel="noopener" style="color: #6ac680; text-decoration: none;" target="_blank">https://gbfs.mex.lyftbikes.com/gbfs/gbfs.json</a> <a> labels
# Found <a download="" href="https://github.com/NABSA/gbfs" rel="noopener" style="color: #6ac680; text-decoration: none;" target="_blank">https://github.com/NABSA/gbfs</a> <a> labels
# Found <a class="elementor-toggle-title" href="">2025</a> <a> labels
# Found <a href="/wp-content/uploads/2025/02/2025-01.csv" rel="noopener" target="_blank">2025-01</a> <a> labels
# Found <a href="/wp-content/uploads/2025/03/2025-02.csv" rel="noopener" target="_blank">2025-02</a> <a> labels
# Found <a href="/wp-content/uploads/2025/04/2025-03.csv" rel="noopener" target="_blank">2025-03</a> <a> labels
# Found <a href="/wp-content/uploads/2025/05/2025-04.csv" rel="noopener" target="_blank">2025-04</a> <a> labels
# Found <a href="/wp-content/uploads/2025/06/2025-05.csv" rel="noopener" target="_blank">2025-05</a> <a> labels
# Found <a href="/wp-content/uploads/2025/07/2025-06.csv" rel="noopener" target="_blank">2025-06</a> <a> labels
# Found <a href="/wp-content/uploads/2025/08/2025-07.csv" rel="noopener" target="_blank">2025-07</a> <a> labels
# Found <a href="/wp-content/uploads/2025/09/2025-08.csv" rel="noopener" target="_blank">2025-08</a> <a> labels
# Found <a href="/wp-content/uploads/2025/10/2025-09.csv" rel="noopener" target="_blank">2025-09</a> <a> labels
# Found <a href="/wp-content/uploads/2025/11/2025-10.csv" rel="noopener" target="_blank">2025-10</a> <a> labels
# Found <a class="elementor-toggle-title" href="">2024</a> <a> labels
# Found <a href="/wp-content/uploads/2024/02/ecobici_2024_enero.csv" rel="noopener" target="_blank">2024-01</a> <a> labels
# Found <a href="/wp-content/uploads/2024/03/2024-02.csv" rel="noopener" target="_blank">2024-02</a> <a> labels
# Found <a href="/wp-content/uploads/2024/04/datos_abiertos_2024_03-1-1.csv" rel="noopener" target="_blank">2024-03</a> <a> labels
# Found <a href="/wp-content/uploads/2024/05/datos_abiertos_2024_04.csv" rel="noopener" target="_blank">2024-04</a> <a> labels
# Found <a href="/wp-content/uploads/2024/06/2024-05-1.csv" rel="noopener" target="_blank">2024-05</a> <a> labels
# Found <a href="/wp-content/uploads/2024/07/2024-06.csv" rel="noopener" target="_blank">2024-06</a> <a> labels
# Found <a href="/wp-content/uploads/2024/08/datos_abiertos_2024_07.csv" rel="noopener" target="_blank">2024-07</a> <a> labels
# Found <a href="/wp-content/uploads/2024/09/2024-08.csv" rel="noopener" target="_blank">2024-08</a> <a> labels
# Found <a href="/wp-content/uploads/2024/10/2024-09.csv" rel="noopener" target="_blank">2024-09</a> <a> labels
# Found <a href="/wp-content/uploads/2024/11/2024-10.csv" rel="noopener" target="_blank">2024-10</a> <a> labels
# Found <a href="/wp-content/uploads/2024/12/2024-11.csv" rel="noopener" target="_blank">2024-11</a> <a> labels
# Found <a href="/wp-content/uploads/2025/01/2024-12.csv" rel="noopener" target="_blank">2024-12</a> <a> labels
# Found <a class="elementor-toggle-title" href="">2023</a> <a> labels
# Found <a href="/wp-content/uploads/2023/10/ecobici_2023_01.csv">2023-01</a> <a> labels
# Found <a href="/wp-content/uploads/2023/10/ecobici_2023_02.csv">2023-02</a> <a> labels
# Found <a href="/wp-content/uploads/2023/10/ecobici_2023_03.csv">2023-03</a> <a> labels
# Found <a href="/wp-content/uploads/2023/10/ecobici_2023_04.csv" rel="noopener" target="_blank">2023-04</a> <a> labels
# Found <a href="/wp-content/uploads/2023/10/ecobici_2023_05.csv" rel="noopener" target="_blank">2023-05</a> <a> labels
# Found <a href="/wp-content/uploads/2023/10/ecobici_2023_06.csv" rel="noopener" target="_blank">2023-06</a> <a> labels
# Found <a href="/wp-content/uploads/2023/10/ecobici_2023_07.csv" rel="noopener" target="_blank">2023-07</a> <a> labels
# Found <a href="/wp-content/uploads/2023/10/ecobici_2023_08.csv" rel="noopener" target="_blank">2023-08</a> <a> labels
# Found <a href="/wp-content/uploads/2023/10/ecobici_2023_09.csv" rel="noopener" target="_blank">2023-09</a> <a> labels
# Found <a href="/wp-content/uploads/2023/11/datosabiertos_2023_octubre.csv" rel="noopener" target="_blank">2023-10</a> <a> labels
# Found <a href="/wp-content/uploads/2023/12/datosabiertos_2023_noviembre.csv" rel="noopener" target="_blank">2023-11</a> <a> labels
# Found <a href="/wp-content/uploads/2024/01/datos_abiertos_2023_diciembre.csv" rel="noopener" target="_blank">2023-12</a> <a> labels
# Found <a class="elementor-toggle-title" href="">2022</a> <a> labels
# Found <a href="/wp-content/uploads/2024/05/2022-01.csv">2022-01</a> <a> labels
# Found <a href="/wp-content/uploads/2024/05/2022-02.csv">2022-02</a> <a> labels
# Found <a href="/wp-content/uploads/2024/05/2022-03.csv">2022-03</a> <a> labels
# Found <a href="/wp-content/uploads/2024/05/2022-04.csv">2022-04</a> <a> labels
# Found <a href="/wp-content/uploads/2024/05/2022-05.csv">2022-05</a> <a> labels
# Found <a href="/wp-content/uploads/2024/05/2022-06.csv">2022-06</a> <a> labels
# Found <a href="/wp-content/uploads/2024/05/2022-07.csv">2022-07</a> <a> labels
# Found <a href="/wp-content/uploads/2023/10/2022-08.csv">2022-08</a> <a> labels
# Found <a href="/wp-content/uploads/2023/08/202209.csv">2022-09</a> <a> labels
# Found <a href="/wp-content/uploads/2023/10/ecobici_2022_10.csv">2022-10</a> <a> labels
# Found <a href="/wp-content/uploads/2023/10/ecobici_2022_11.csv">2022-11</a> <a> labels
# Found <a href="/wp-content/uploads/2023/10/ecobici_2022_12.csv">2022-12</a> <a> labels
# Found <a class="elementor-toggle-title" href="">2021</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2021-01.csv">2021-01</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2021-02.csv">2021-02</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2021-03.csv">2021-03</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2021-04.csv">2021-04</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2021-05.csv">2021-05</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2021-06.csv">2021-06</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2021-07.csv">2021-07</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2021-08.csv">2021-08</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2021-09.csv">2021-09</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2021-10.csv">2021-10</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2021-11.csv">2021-11</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2021-12.csv">2021-12</a> <a> labels
# Found <a class="elementor-toggle-title" href="">2020</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2020-01.csv">2020-01</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2020-02.csv">2020-02</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2020-03.csv">2020-03</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2020-04.csv">2020-04</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2020-05.csv">2020-05</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2020-06.csv">2020-06</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2020-07.csv">2020-07</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2020-08.csv">2020-08</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2020-09.csv">2020-09</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2020-10.csv">2020-10</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2020-11.csv">2020-11</a> <a> labels
# Found <a href="/wp-content/uploads/2023/08/2020-12.csv">2020-12</a> <a> labels
# Found <a class="elementor-toggle-title" href="">2019</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2019-01.csv">2019-01</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2019-02.csv">2019-02</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2019-03.csv">2019-03</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2019-04.csv">2019-04</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2019-05.csv">2019-05</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2019-06.csv">2019-06</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2019-07.csv">2019-07</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2019-08.csv">2019-08</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2019-09.csv">2019-09</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2019-10.csv">2019-10</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2019-11.csv">2019-11</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2019-12.csv">2019-12</a> <a> labels
# Found <a class="elementor-toggle-title" href="">2018</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2018-01.csv">2018-01</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2018-02.csv">2018-02</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2018-03.csv">2018-03</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2018-04.csv">2018-04</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2018-05.csv">2018-05</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2018-06.csv">2018-06</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2018-07.csv">2018-07</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2018-08.csv">2018-08</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2018-09.csv">2018-09</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2018-10.csv">2018-10</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2018-11.csv">2018-11</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2018-12.csv">2018-12</a> <a> labels
# Found <a class="elementor-toggle-title" href="">2017</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2017-01.csv">2017-01</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2017-02.csv">2017-02</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2017-03.csv">2017-03</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2017-04.csv">2017-04</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2017-05.csv">2017-05</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2017-06.csv">2017-06</a> <a> labels
# Found <a href="/wp-content/uploads/2022/09/2017-07.csv">2017-07</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2017-08.csv">2017-08</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2017-09.csv">2017-09</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2017-10.csv">2017-10</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2017-11.csv">2017-11</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2017-12.csv">2017-12</a> <a> labels
# Found <a class="elementor-toggle-title" href="">2016</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2016-01.csv">2016-01</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2016-02.csv">2016-02</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2016-03.csv">2016-03</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2016-04.csv">2016-04</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2016-05.csv">2016-05</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2016-06.csv">2016-06</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2016-07.csv">2016-07</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2016-08.csv">2016-08</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2016-09.csv">2016-09</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2016-10.csv">2016-10</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2016-11.csv">2016-11</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2016-12.csv">2016-12</a> <a> labels
# Found <a class="elementor-toggle-title" href="">2015</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2015-01.csv">2015-01</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2015-02.csv">2015-02</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2015-03.csv">2015-03</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2015-04.csv">2015-04</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2015-05.csv">2015-05</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2015-06.csv">2015-06</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2015-07.csv">2015-07</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2015-08.csv">2015-08</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2015-09.csv">2015-09</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2015-10.csv">2015-10</a> <a> labels
# Found <a href="/wp-content/uploads/2022/09/2015-11.csv">2015-11</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2015-12.csv">2015-12</a> <a> labels
# Found <a class="elementor-toggle-title" href="">2014</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2014-01.csv">2014-01</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2014-02.csv">2014-02</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2014-03.csv">2014-03</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2014-04.csv">2014-04</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2014-05.csv">2014-05</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2014-06.csv">2014-06</a> <a> labels
# Found <a href="/wp-content/uploads/2022/09/2014-07.csv">2014-07</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2014-08.csv">2014-08</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2014-09.csv">2014-09</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2014-10.csv">2014-10</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2014-11.csv">2014-11</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2014-12.csv">2014-12</a> <a> labels
# Found <a class="elementor-toggle-title" href="">2013</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2013-01.csv">2013-01</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2013-02.csv">2013-02</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2013-03.csv">2013-03</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2013-04.csv">2013-04</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2013-05.csv">2013-05</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2013-06.csv">2013-06</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2013-07.csv">2013-07</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2013-08.csv">2013-08</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2013-09.csv">2013-09</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2013-10.csv">2013-10</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2013-11.csv">2013-11</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2013-12.csv">2013-12</a> <a> labels
# Found <a class="elementor-toggle-title" href="">2012</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2012-01.csv">2012-01</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2012-02.csv">2012-02</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2012-03.csv">2012-03</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2012-04.csv">2012-04</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2012-05.csv">2012-05</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2012-06.csv">2012-06</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2012-07.csv">2012-07</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2012-08.csv">2012-08</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2012-09.csv" style="font-size: inherit; background-color: #ffffff;">2012-09</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2012-10.csv">2012-10</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2012-11.csv">2012-11</a> <a> labels
# Found <a href="/wp-content/uploads/2022/08/2012-12.csv">2012-12</a> <a> labels
# Found <a class="elementor-toggle-title" href="">2011</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2011-01-ene.csv">2011-01</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2011-02.csv">2011-02</a> <a> labels
# Found <a href="/wp-content/uploads/2022/09/2011-03.csv">2011-03</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2011-04.csv">2011-04</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2011-05.csv">2011-05</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2011-06.csv">2011-06</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2011-07.csv">2011-07</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2011-08.csv">2011-08</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2011-09.csv">2011-09</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2011-10.csv">2011-10</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2011-11.csv">2011-11</a> <a> labels
# Found <a href="/wp-content/uploads/2022/07/2011-12.csv">2011-12</a> <a> labels
# Found <a class="elementor-toggle-title" href="">2010</a> <a> labels
# Found <a href="/wp-content/uploads/2022/06/2010-02-feb.csv">2010-02</a> <a> labels
# Found <a href="/wp-content/uploads/2022/06/2010-03-mar.csv">2010-03</a> <a> labels
# Found <a href="/wp-content/uploads/2022/06/2010-04-abr.csv">2010-04</a> <a> labels
# Found <a href="/wp-content/uploads/2022/06/2010-05-may.csv" style="font-size: inherit; background-color: #ffffff;">2010-05</a> <a> labels
# Found <a href="/wp-content/uploads/2022/06/2010-06-jun.csv" style="font-size: inherit; background-color: #ffffff;">2010-06</a> <a> labels
# Found <a href="/wp-content/uploads/2022/06/2010-07-jul.csv" style="font-size: inherit; background-color: #ffffff;">2010-07</a> <a> labels
# Found <a href="/wp-content/uploads/2022/06/2010-08-ago.csv" style="font-size: inherit; background-color: #ffffff;">2010-08</a> <a> labels
# Found <a href="/wp-content/uploads/2022/06/2010-09-sep.csv" style="font-size: inherit; background-color: #ffffff;">2010-09</a> <a> labels
# Found <a href="/wp-content/uploads/2022/06/2010-10-oct.csv" style="font-size: inherit; background-color: #ffffff;">2010-10</a> <a> labels
# Found <a href="/wp-content/uploads/2022/06/2010-11-nov.csv" style="font-size: inherit; background-color: #ffffff;">2010-11</a> <a> labels
# Found <a href="/wp-content/uploads/2022/06/2010-12-dic.csv" style="font-size: inherit; background-color: #ffffff;">2010-12</a> <a> labels
# Found <a href="/">
# <img alt="" class="attachment-full size-full" height="440" loading="lazy" sizes="(max-width: 2396px) 100vw, 2396px" src="/wp-content/uploads/2019/12/0ecobici_imagotipo.png" srcset="/wp-content/uploads/2019/12/0ecobici_imagotipo.png 2396w, /wp-content/uploads/2019/12/0ecobici_imagotipo-360x66.png 360w, /wp-content/uploads/2019/12/0ecobici_imagotipo-1500x275.png 1500w, /wp-content/uploads/2019/12/0ecobici_imagotipo-840x154.png 840w, /wp-content/uploads/2019/12/0ecobici_imagotipo-1536x282.png 1536w, /wp-content/uploads/2019/12/0ecobici_imagotipo-2048x376.png 2048w, /wp-content/uploads/2019/12/0ecobici_imagotipo-436x80.png 436w" width="2396"/> </a> <a> labels
# Found <a href="/">
# <span class="elementor-icon-list-text">Inicio</span>
# </a> <a> labels
# Found <a href="/conoce-sistema/">
# <span class="elementor-icon-list-text">Ecobici</span>
# </a> <a> labels
# Found <a href="/planes-y-tarifas/">
# <span class="elementor-icon-list-text">Planes y tarifas</span>
# </a> <a> labels
# Found <a href="/mapa/">
# <span class="elementor-icon-list-text">Mapa</span>
# </a> <a> labels
# Found <a href="/noticias/">
# <span class="elementor-icon-list-text">Noticias</span>
# </a> <a> labels
# Found <a href="/preguntas-frecuentes/">
# <span class="elementor-icon-list-text">Preguntas frecuentes</span>
# </a> <a> labels
# Found <a href="/mapa-del-sitio/">
# <span class="elementor-icon-list-text">Mapa del sitio</span>
# </a> <a> labels
# Found <a href="/contrato-adhesion/" target="_blank">
# <span class="elementor-icon-list-text">Contrato de adhesión</span>
# </a> <a> labels
# Found <a href="/aviso-privacidad/">
# <span class="elementor-icon-list-text">Aviso de privacidad</span>
# </a> <a> labels
# Found <a href="/documentos/carta-autorizacion-menores/">
# <span class="elementor-icon-list-text">Carta de autorización de menores</span>
# </a> <a> labels
# Found <a href="/terminos-condiciones/">
# <span class="elementor-icon-list-text">Términos y condiciones</span>
# </a> <a> labels
# Found <a href="/contacto/">
# <span class="elementor-icon-list-text">Contacto</span>
# </a> <a> labels
# Found <a href="tel:5550052424">
# <span class="elementor-icon-list-icon">
# <i aria-hidden="true" class="fas fa-phone-square-alt"></i> </span>
# <span class="elementor-icon-list-text">55 5005 2424</span>
# </a> <a> labels
# Found <a href="tel:8003262421">
# <span class="elementor-icon-list-icon">
# <i aria-hidden="true" class="fas fa-phone-square-alt"></i> </span>
# <span class="elementor-icon-list-text">800 3262 421</span>
# </a> <a> labels
# Found <a href="https://wa.me/+528003262421">
# <span class="elementor-icon-list-icon">
# <i aria-hidden="true" class="fab fa-whatsapp-square"></i> </span>
# <span class="elementor-icon-list-text">800 3262 421</span>
# </a> <a> labels
# Found <a href="https://usuario.ecobici.cdmx.gob.mx/sign-in" rel="noopener" target="_blank">Soy usuario registrado</a> <a> labels
# Found <a class="elementor-button-link elementor-button elementor-size-md" href="https://usuario.ecobici.cdmx.gob.mx/" role="button">
# <span class="elementor-button-content-wrapper">
# <span class="elementor-button-text">Regístrate</span>
# </span>
# </a> <a> labels
# Found <a class="elementor-icon elementor-social-icon elementor-social-icon-facebook-square elementor-repeater-item-c043033" href="https://es-la.facebook.com/ecobici/" target="_blank">
# <span class="elementor-screen-only">Facebook-square</span>
# <i class="fab fa-facebook-square"></i> </a> <a> labels
# Found <a class="elementor-icon elementor-social-icon elementor-social-icon- elementor-repeater-item-775fab6" href="https://twitter.com/ecobici" target="_blank">
# <span class="elementor-screen-only"></span>
# <svg viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg"><path d="M64 32C28.7 32 0 60.7 0 96V416c0 35.3 28.7 64 64 64H384c35.3 0 64-28.7 64-64V96c0-35.3-28.7-64-64-64H64zm297.1 84L257.3 234.6 379.4 396H283.8L209 298.1 123.3 396H75.8l111-126.9L69.7 116h98l67.7 89.5L313.6 116h47.5zM323.3 367.6L153.4 142.9H125.1L296.9 367.6h26.3z"></path></svg> </a> <a> labels
# Found <a class="elementor-icon elementor-social-icon elementor-social-icon-instagram elementor-repeater-item-ac84b58" href="https://www.instagram.com/ecobicicdmx/?hl=es" target="_blank">
# <span class="elementor-screen-only">Instagram</span>
# <i class="fab fa-instagram"></i> </a> <a> labels
#
# Total <a> labels found: 270

# %%
# Filtering <a> labels .csv

links_csvs = []

base_url = "https://ecobici.cdmx.gob.mx"

for csvs in all_links:
    csv_href = csvs.get('href')
    if csv_href:
        if ".csv" in csv_href:
            links_csvs.append(base_url+csv_href)

print("-- Links found --")
print(f"Csvs found: {len(links_csvs)}")

# slicing list
links_csvs_limit = links_csvs[7:10]

print(f"\nTotal csvs used: {len(links_csvs_limit)}")
print(links_csvs_limit)
# Out:
# -- Links found --
# Csvs found: 189
#
# Total csvs used: 3
# ['https://ecobici.cdmx.gob.mx/wp-content/uploads/2025/09/2025-08.csv', 'https://ecobici.cdmx.gob.mx/wp-content/uploads/2025/10/2025-09.csv', 'https://ecobici.cdmx.gob.mx/wp-content/uploads/2025/11/2025-10.csv']

# %% [markdown]
# ### 1.3: Using Pandas for download and concat files

# %%
# save dataframe we'll use
df_list = []
print(f'Start downloading and lecture: {len(links_csvs_limit)} files')

for url in links_csvs_limit:
    print(f"Processing: {url.split('/')[-1]}")
    df_temporal = pd.read_csv(url)
    df_list.append(df_temporal)
    
print("All files were processed")
# Out:
# Start downloading and lecture: 3 files
# Processing: 2025-08.csv
# Processing: 2025-09.csv
# Processing: 2025-10.csv
# All files were processed

# %%
# Merge files 
print(f"Merging all files in one single Dataframe Master")
df_master = pd.concat(df_list)
print("--- ¡Completed! ---")
# Out:
# Merging all files in one single Dataframe Master
# --- ¡Completed! ---

# %%
print(f"Dimensions dataframe: {df_master.shape}")
# Out:
# Dimensions dataframe: (4951828, 9)

# %%
df_master.head()
# Out:
#   Genero_Usuario  Edad_Usuario     Bici Ciclo_Estacion_Retiro Fecha_Retiro  \
# 0              F          42.0  6401327               107-108   31/07/2025
# 1              M          27.0  8063216                   140   31/07/2025
# 2              F          22.0  3710100                   141   31/07/2025
# 3              M          24.0  6243661                   548   31/07/2025
# 4              M          25.0  4258406                   567   31/07/2025
#
#   Hora_Retiro Ciclo_EstacionArribo Fecha_Arribo Hora_Arribo
# 0    23:51:05                  104   01/08/2025    00:00:07
# 1    23:54:46              158-159   01/08/2025    00:00:13
# 2    23:55:49              158-159   01/08/2025    00:00:29
# 3    23:48:39                  482   01/08/2025    00:00:29
# 4    23:40:31                  567   01/08/2025    00:00:33

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4951828 entries, 0 to 1754352
# Data columns (total 9 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Genero_Usuario         object
#  1   Edad_Usuario           float64
#  2   Bici                   int64
#  3   Ciclo_Estacion_Retiro  object
#  4   Fecha_Retiro           object
#  5   Hora_Retiro            object
#  6   Ciclo_EstacionArribo   object
#  7   Fecha_Arribo           object
#  8   Hora_Arribo            object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 377.8+ MB

# %% [markdown]
# ### 1.5: Transforming

# %% [markdown]
# We will use an time_difference KPI, we need to modify/convert columns dates

# %%
# Create new column Timestamp for Leaving-Retiro and Arriving- Arribo
df_master['Timestamp_Retiro'] = df_master['Fecha_Retiro'] + ' ' + df_master['Hora_Retiro']

df_master['Timestamp_Arribo'] = df_master['Fecha_Arribo'] + ' ' + df_master['Hora_Arribo']

# %%
# Convert datatype to timestamp date
# Set format
date_format = '%d/%m/%Y %H:%M:%S'

# %%
df_master['Timestamp_Retiro'] = pd.to_datetime(df_master['Timestamp_Retiro'], format=date_format)

df_master['Timestamp_Arribo'] = pd.to_datetime(df_master['Timestamp_Arribo'], format=date_format)

print('Dates transformed')
# Out:
# Dates transformed

# %%
# creating metric- time difference 
diferencia_tiempo = df_master['Timestamp_Arribo'] - df_master['Timestamp_Retiro']

# %%
# convert to minutes
# create new columne time difference
df_master['Duracion_Minutos'] = diferencia_tiempo.dt.total_seconds() / 60

# %%
df_master[['Timestamp_Retiro', 'Timestamp_Arribo', 'Duracion_Minutos']].head()
# Out:
#      Timestamp_Retiro    Timestamp_Arribo  Duracion_Minutos
# 0 2025-07-31 23:51:05 2025-08-01 00:00:07          9.033333
# 1 2025-07-31 23:54:46 2025-08-01 00:00:13          5.450000
# 2 2025-07-31 23:55:49 2025-08-01 00:00:29          4.666667
# 3 2025-07-31 23:48:39 2025-08-01 00:00:29         11.833333
# 4 2025-07-31 23:40:31 2025-08-01 00:00:33         20.033333

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4951828 entries, 0 to 1754352
# Data columns (total 12 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Genero_Usuario         object
#  1   Edad_Usuario           float64
#  2   Bici                   int64
#  3   Ciclo_Estacion_Retiro  object
#  4   Fecha_Retiro           object
#  5   Hora_Retiro            object
#  6   Ciclo_EstacionArribo   object
#  7   Fecha_Arribo           object
#  8   Hora_Arribo            object
#  9   Timestamp_Retiro       datetime64[ns]
#  10  Timestamp_Arribo       datetime64[ns]
#  11  Duracion_Minutos       float64
# dtypes: datetime64[ns](2), float64(2), int64(1), object(7)
# memory usage: 491.1+ MB

# %%
df_master['Genero_Usuario'].unique()
# Out:
# array(['F', 'M', 'O', '?', nan], dtype=object)

# %%
df_master['Edad_Usuario'].isna().sum()
# Out:
# 223

# %%
df_master['Bici'].isna().sum()
# Out:
# 0

# %%
df_master['Ciclo_Estacion_Retiro'].unique()
# Out:
# array(['107-108', '140', '141', '548', '567', '044', '074', '013', '137',
#        '237-238', '491', '397', '428', '068', '449', '389', '087', '031',
#        '072', '480', '178', '073', '064', '082', '447', '192-193', '259',
#        '040', '119', '216', '131', '270', '123', '133', '675', '170',
#        '205', '045', '151', '144', '057', '271-272', '504', '034', '595',
#        '256', '118', '091', '458', '651', '223', '242', '496', '624',
#        '055', '221', '260', '462', '128', '603', '402', '029', '041',
#        '047', '606', '708', '025', '048', '481', '545', '494', '027',
#        '381', '042', '061', '517', '373', '386', '277', '563', '551',
#        '513', '121', '208', '028', '209', '455', '250', '372', '257',
#        '217', '464', '083', '134', '030', '502', '075', '546', '166',
#        '398', '399', '495', '361', '009', '529', '049', '584', '135',
#        '336', '008', '230', '476', '032', '553', '244', '359', '444',
#        '401', '578', '126', '598', '052', '568', '006', '069', '054',
#        '051', '142', '017', '130', '099', '674', '258', '288', '079',
#        '106', '127', '600', '299', '292', '015', '200', '577', '239',
#        '638', '519', '252', '407', '669', '370', '325', '201', '468',
#        '384', '615', '077', '168', '537', '544', '329', '612', '016',
#        '024', '522', '328', '591', '321', '510', '617', '036', '155',
#        '484', '562', '255', '086', '125', '626', '492', '523', '512',
#        '117', '174', '488', '530', '654', '559', '160', '437', '524',
#        '594', '445-446', '424', '210', '690', '265', '448', '149', '374',
#        '555', '489', '450', '154', '035', '390-391', '499', '597', '573',
#        '540', '646', '302', '409', '185', '535', '369', '641', '132',
#        '429', '286', '169', '590', '053', '156', '067', '613', '516',
#        '014', '623', '085', '351', '466', '461', '020', '539', '644',
#        '493', '187', '189', '186', '378', '366', '630', '565', '533',
#        '440', '485', '627', '678', '479', '575', '541', '062', '618',
#        '463', '611', '093', '231', '419', '637', '538', '145', '254',
#        '060', '282', '002', '632', '348', '487', '313', '439', '365',
#        '181', '394', '005', '103', '100', '706', '629', '534', '550',
#        '327', '262', '685', '147', '225', '656', '320', '569', '557',
#        '680', '469', '347', '171', '266-267', '465', '293', '610', '084',
#        '576', '111', '164', '711', '172', '001', '183', '561', '211',
#        '324', '420', '566', '175', '199', '668', '451', '188', '253',
#        '136', '454', '709', '614', '471', '549', '683', '281', '560',
#        '295', '355', '197', '643', '245', '385', '180', '124', '608',
#        '413', '703', '003', '011', '195', '010', '148', '309', '501',
#        '459', '689', '110', '356', '500', '089', '341', '235-236', '173',
#        '280', '581', '505', '112', '508', '543', '070', '430', '090',
#        '138', '352', '601', '554', '163', '556', '532', '276', '503',
#        '165', '570', '511', '371', '113', '525', '460', '635', '441',
#        '620', '317', '628', '422', '063', '506', '129', '007', '297',
#        '692', '542', '580', '521', '602', '310', '023', '486', '702',
#        '043', '105', '631', '153', '473', '304', '360', '363', '434',
#        '287', '490', '278', '318', '179', '263', '150', '233', '191',
#        '081', '116', '393', '453', '298', '284', '294', '291', '414',
#        '478', '102', '592', '558', '404', '670', '625', '098', '268-269',
#        '607', '405', '609', '457', '358', '340', '307', '536', '194',
#        '207', '572', '349', '679', '497', '059', '037', '228', '432',
#        '066', '705', '204', '588', '526', '604', '219', '652', '158-159',
#        '214', '332', '056', '642', '322', '190', '038', '232', '323',
#        '552', '143', '663', '427', '645', '314', '182', '019', '593',
#        '078', '362', '507', '621', '088', '691', '395', '633', '096',
#        '589', '146', '342', '308', '599', '640', '649', '004', '377',
#        '470', '312', '547', '162', '528', '248', '622', '474', '326',
#        '022', '616', '337', '438', '518', '596', '283', '021', '319',
#        '050', '564', '251', '583', '688', '660', '184', '296', '667',
#        '046', '080', '065', '120', '392', '412', '139', '514', '234',
#        '012', '520', '585', '333', '582', '285', '264-275', '018', '467',
#        '306', '676', '396', '498', '330', '421', '226', '115', '417',
#        '661', '104', '338', '220', '215', '475', '677', '574', '619',
#        '300', '380', '456', '218', '416', '290', '095', '579', '515',
#        '586', '571', '696', '605', '698', '387', '684', '673', '367',
#        '334', '301', '331', '092', '167', '196', '076', '639', '587',
#        '697', '161', '249', '246', '695', '094', '648', '273-274', '033',
#        '423', '357', '227', '672', '634', '212', '527', '682', '039',
#        '636', '659', '222', '026', '671', '202', '243', '176', '279',
#        '699', '415', '071', '097', '247', '345', '483', '229', '305',
#        '224', '657', '122', '704', '531', '343', '693', '710', '203',
#        '425', '655', '316', '686', '339', '157', '707', '452', '687',
#        '303', '509', '241', '177', '213', '477', '436', '681', '701',
#        '433', '482', '647', '058', '650', '198', '114', '665', '664',
#        '109', '443', '375', '658', '653', '152', '472', '354', '694',
#        '666', '442', '700', '662', '206', '315', '261', '353', '346',
#        '335', '240', '1000'], dtype=object)

# %%
df_master['Ciclo_EstacionArribo'].unique()
# Out:
# array(['104', '158-159', '482', '567', '111', '205', '563', '035', '160',
#        '405', '430', '032', '062', '634', '573', '262', '538', '271-272',
#        '466', '016', '083', '167', '612', '001', '571', '002', '109',
#        '256', '595', '594', '172', '217', '141', '532', '182', '145',
#        '034', '685', '287', '169', '613', '579', '545', '152', '485',
#        '448', '181', '591', '291', '260', '031', '617', '221', '506',
#        '497', '636', '130', '073', '270', '183', '540', '051', '489',
#        '620', '029', '074', '065', '146', '144', '602', '708', '577',
#        '565', '091', '011', '488', '209', '086', '553', '534', '263',
#        '356', '580', '522', '175', '310', '370', '106', '064', '025',
#        '510', '244', '464', '092', '470', '237-238', '107-108', '505',
#        '286', '013', '298', '325', '015', '047', '028', '551', '179',
#        '413', '407', '501', '066', '110', '155', '008', '219', '071',
#        '645', '502', '544', '555', '481', '372', '068', '061', '409',
#        '578', '258', '550', '554', '308', '133', '134', '099', '006',
#        '637', '548', '572', '495', '566', '528', '596', '317', '575',
#        '348', '649', '586', '088', '281', '125', '651', '465', '040',
#        '546', '127', '085', '136', '190', '487', '642', '139', '450',
#        '143', '562', '077', '483', '303', '541', '560', '385', '626',
#        '184', '496', '185', '170', '608', '268-269', '447', '668', '374',
#        '601', '171', '023', '401', '398', '461', '340', '354', '148',
#        '033', '261', '019', '627', '477', '087', '014', '121', '257',
#        '201', '513', '113', '659', '467', '644', '436', '593', '373',
#        '230', '223', '419', '150', '041', '542', '129', '116', '009',
#        '369', '402', '390-391', '683', '197', '284', '640', '621', '157',
#        '208', '412', '027', '233', '472', '059', '378', '048', '302',
#        '117', '131', '017', '377', '192-193', '084', '475', '012', '018',
#        '030', '474', '142', '296', '042', '187', '694', '010', '250',
#        '166', '080', '026', '105', '490', '149', '049', '432', '684',
#        '663', '334', '445-446', '460', '404', '277', '215', '037', '597',
#        '479', '635', '024', '242', '459', '046', '476', '423', '318',
#        '381', '672', '478', '326', '393', '616', '200', '224', '212',
#        '053', '174', '669', '648', '290', '389', '082', '678', '655',
#        '367', '630', '007', '156', '416', '162', '589', '225', '468',
#        '198', '584', '279', '112', '503', '020', '347', '058', '226',
#        '494', '063', '253', '455', '003', '195', '021', '060', '463',
#        '078', '137', '124', '282', '359', '521', '231', '633', '038',
#        '420', '295', '628', '255', '280', '266-267', '214', '022', '603',
#        '397', '004', '346', '623', '056', '686', '206', '384', '399',
#        '194', '576', '536', '606', '070', '043', '507', '132', '147',
#        '135', '632', '363', '657', '292', '094', '249', '588', '090',
#        '486', '299', '235-236', '688', '449', '531', '288', '675', '585',
#        '543', '115', '491', '552', '052', '653', '660', '199', '512',
#        '227', '328', '529', '234', '471', '349', '537', '297', '558',
#        '526', '039', '096', '341', '614', '251', '338', '395', '451',
#        '123', '097', '188', '232', '005', '178', '177', '304', '069',
#        '220', '045', '582', '316', '228', '590', '163', '154', '386',
#        '265', '556', '652', '421', '323', '098', '618', '128', '054',
#        '691', '709', '327', '547', '473', '079', '210', '247', '180',
#        '444', '641', '710', '036', '638', '207', '202', '605', '533',
#        '498', '492', '695', '427', '081', '329', '211', '667', '246',
#        '484', '417', '259', '196', '690', '294', '703', '337', '057',
#        '245', '241', '248', '165', '458', '055', '480', '469', '438',
#        '610', '072', '173', '456', '240', '705', '647', '331', '285',
#        '301', '524', '222', '126', '511', '387', '335', '452', '692',
#        '075', '358', '499', '677', '392', '394', '336', '598', '682',
#        '425', '243', '140', '339', '535', '309', '315', '151', '516',
#        '504', '305', '186', '300', '453', '076', '164', '415', '114',
#        '375', '333', '352', '530', '120', '440', '693', '324', '520',
#        '278', '216', '700', '138', '380', '523', '600', '239', '396',
#        '564', '646', '439', '680', '609', '539', '568', '306', '332',
#        '161', '119', '493', '592', '443', '357', '624', '441', '454',
#        '050', '509', '252', '345', '557', '581', '570', '414', '662',
#        '514', '696', '689', '615', '273-274', '424', '320', '654', '191',
#        '508', '095', '100', '549', '611', '666', '089', '517', '462',
#        '437', '351', '168', '118', '067', '681', '656', '229', '699',
#        '343', '312', '103', '583', '366', '307', '661', '711', '203',
#        '360', '457', '500', '283', '361', '213', '293', '355', '322',
#        '254', '670', '434', '122', '428', '264-275', '704', '362', '604',
#        '587', '518', '153', '631', '650', '371', '679', '321', '515',
#        '706', '342', '519', '676', '559', '658', '330', '622', '102',
#        '698', '442', '625', '313', '527', '643', '697', '365', '319',
#        '671', '673', '639', '276', '353', '044', '619', '204', '561',
#        '629', '433', '525', '189', '176', '429', '599', '674', '702',
#        '093', '314', '665', '422', '607', '687', '574', '701', '707',
#        '569', '218', '664', '1000',
#        'Temporal - 2da Sección Bosque Chapultepec'], dtype=object)

# %%
df_master[(df_master['Bici'] == 8205254) & (df_master['Edad_Usuario']==50)]
# Out:
#         Genero_Usuario  Edad_Usuario     Bici Ciclo_Estacion_Retiro  \
# 102765               M          50.0  8205254                   545
# 1293332              M          50.0  8205254                   170
# 682661               M          50.0  8205254                   641
# 1001666              M          50.0  8205254                   189
# 1257401              M          50.0  8205254                   340
# 1490812              M          50.0  8205254                   089
# 1492805              M          50.0  8205254                   559
# 1502048              M          50.0  8205254                   627
# 887604               M          50.0  8205254                   293
# 1497657              M          50.0  8205254                   292
# 1619581              M          50.0  8205254                   282
#
#         Fecha_Retiro Hora_Retiro                       Ciclo_EstacionArribo  \
# 102765    03/08/2025    13:49:44                                        544
# 1293332   26/08/2025    09:31:24                                        473
# 682661    13/09/2025    10:13:16                                        639
# 1001666   19/09/2025    23:54:14                                        152
# 1257401   24/09/2025    19:01:44                                        277
# 1490812   29/09/2025    16:15:58                                        559
# 1492805   29/09/2025    16:31:17                                        630
# 1502048   29/09/2025    18:34:49                                        616
# 887604    17/10/2025    09:52:02  Temporal - 2da Sección Bosque Chapultepec
# 1497657   28/10/2025    07:40:28                                        360
# 1619581   29/10/2025    20:38:02                                        597
#
#         Fecha_Arribo Hora_Arribo    Timestamp_Retiro    Timestamp_Arribo  \
# 102765    03/08/2025    13:51:52 2025-08-03 13:49:44 2025-08-03 13:51:52
# 1293332   26/08/2025    09:59:36 2025-08-26 09:31:24 2025-08-26 09:59:36
# 682661    13/09/2025    10:17:33 2025-09-13 10:13:16 2025-09-13 10:17:33
# 1001666   20/09/2025    00:06:49 2025-09-19 23:54:14 2025-09-20 00:06:49
# 1257401   24/09/2025    19:12:26 2025-09-24 19:01:44 2025-09-24 19:12:26
# 1490812   29/09/2025    16:29:10 2025-09-29 16:15:58 2025-09-29 16:29:10
# 1492805   29/09/2025    16:57:21 2025-09-29 16:31:17 2025-09-29 16:57:21
# 1502048   29/09/2025    18:38:07 2025-09-29 18:34:49 2025-09-29 18:38:07
# 887604    17/10/2025    09:56:48 2025-10-17 09:52:02 2025-10-17 09:56:48
# 1497657   28/10/2025    08:08:18 2025-10-28 07:40:28 2025-10-28 08:08:18
# 1619581   29/10/2025    20:44:49 2025-10-29 20:38:02 2025-10-29 20:44:49
#
#          Duracion_Minutos
# 102765           2.133333
# 1293332         28.200000
# 682661           4.283333
# 1001666         12.583333
# 1257401         10.700000
# 1490812         13.200000
# 1492805         26.066667
# 1502048          3.300000
# 887604           4.766667
# 1497657         27.833333
# 1619581          6.783333

# %% [markdown]
# ## Connect to MySQL Workbench

# %% [markdown]
# ### 2.1: Installing PyMySQL

# %%
# !pip install PyMySQL
# Out:
# Collecting PyMySQL
#   Downloading pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# Downloading pymysql-1.1.2-py3-none-any.whl (45 kB)
# Installing collected packages: PyMySQL
# Successfully installed PyMySQL-1.1.2

# %% [markdown]
# ### 2.2: Create Database in MySQL

# %% [markdown]
# ### 2.3: Connection MySQL

# %%
import sqlalchemy

usuario = 'root'
contrasena = 'abcd1234'
host = '127.0.0.1'
basedatos = 'ecobici_db'

print("Creating connection to MySQL")
engine = sqlalchemy.create_engine(f"mysql+pymysql://{usuario}:{contrasena}@{host}/{basedatos}")

print(f"Loading {df_master.shape[0]} rows to Database")

df_master.to_sql(
    name='viajes',
    con=engine,
    if_exists='replace',
    index=False,
    chunksize=10000   
)

print("Loaded Successful, Data stored in ecobici_db ")
# Out:
# Creating connection to MySQL
# Loading 4951828 rows to Database
# Loaded Successful, Data stored in ecobici_db
